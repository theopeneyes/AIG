# %% [markdown]
# # **Installing Libraries**

# %%
# !pip install transformers==2.5.1
# !pip install datasets evaluate transformers[sentencepiece]
# !pip install sentencepiece
# !pip install transformers[torch]==4.3
# !pip install torch
# !pip install tika
# !pip install aspose-words
# Out:
# Collecting transformers==2.5.1
#   Using cached transformers-2.5.1-py3-none-any.whl (499 kB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\developer14\anaconda3\lib\site-packages (from transformers==2.5.1) (2022.3.15)
# Requirement already satisfied: numpy in c:\users\developer14\anaconda3\lib\site-packages (from transformers==2.5.1) (1.21.5)
# Requirement already satisfied: requests in c:\users\developer14\anaconda3\lib\site-packages (from transformers==2.5.1) (2.27.1)
# Requirement already satisfied: boto3 in c:\users\developer14\anaconda3\lib\site-packages (from transformers==2.5.1) (1.21.32)
# Requirement already satisfied: filelock in c:\users\developer14\anaconda3\lib\site-packages (from transformers==2.5.1) (3.6.0)
# Collecting tokenizers==0.5.2
#   Using cached tokenizers-0.5.2.tar.gz (64 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: sacremoses in c:\users\developer14\anaconda3\lib\site-packages (from transformers==2.5.1) (0.0.53)
# Requirement already satisfied: sentencepiece in c:\users\developer14\anaconda3\lib\site-packages (from transformers==2.5.1) (0.1.97)
# Requirement already satisfied: tqdm>=4.27 in c:\users\developer14\anaconda3\lib\site-packages (from transformers==2.5.1) (4.64.0)
# Requirement already satisfied: colorama in c:\users\developer14\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==2.5.1) (0.4.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\developer14\anaconda3\lib\site-packages (from boto3->transformers==2.5.1) (0.10.0)
# Requirement already satisfied: botocore<1.25.0,>=1.24.32 in c:\users\developer14\anaconda3\lib\site-packages (from boto3->transformers==2.5.1) (1.24.32)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\developer14\anaconda3\lib\site-packages (from boto3->transformers==2.5.1) (0.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\developer14\anaconda3\lib\site-packages (from botocore<1.25.0,>=1.24.32->boto3->transformers==2.5.1) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\developer14\anaconda3\lib\site-packages (from botocore<1.25.0,>=1.24.32->boto3->transformers==2.5.1) (1.26.9)
# Requirement already satisfied: six>=1.5 in c:\users\developer14\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.25.0,>=1.24.32->boto3->transformers==2.5.1) (1.16.0)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\developer14\Anaconda3\python.exe' 'C:\Users\developer14\Anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\DEVELO~1\AppData\Local\Temp\tmp2t41gct2'
#        cwd: C:\Users\developer14\AppData\Local\Temp\pip-install-ji4fynus\tokenizers_ef62438364454be4ad83f0f27547ee0a
#   Complete output (46 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\tokenizers
#   copying tokenizers\__init__.py -> build\lib.win-amd64-cpython-39\tokenizers
#   creating build\lib.win-amd64-cpython-39\tokenizers\models
#   copying tokenizers\models\__init__.py -> build\lib.win-amd64-cpython-39\tokenizers\models
#   creating build\lib.win-amd64-cpython-39\tokenizers\decoders
#   copying tokenizers\decoders\__init__.py -> build\lib.win-amd64-cpython-39\tokenizers\decoders
#   creating build\lib.win-amd64-cpython-39\tokenizers\normalizers
#   copying tokenizers\normalizers\__init__.py -> build\lib.win-amd64-cpython-39\tokenizers\normalizers
#   creating build\lib.win-amd64-cpython-39\tokenizers\pre_tokenizers
#   copying tokenizers\pre_tokenizers\__init__.py -> build\lib.win-amd64-cpython-39\tokenizers\pre_tokenizers
#   creating build\lib.win-amd64-cpython-39\tokenizers\processors
#   copying tokenizers\processors\__init__.py -> build\lib.win-amd64-cpython-39\tokenizers\processors
#   creating build\lib.win-amd64-cpython-39\tokenizers\trainers
#   copying tokenizers\trainers\__init__.py -> build\lib.win-amd64-cpython-39\tokenizers\trainers
#   creating build\lib.win-amd64-cpython-39\tokenizers\implementations
#   copying tokenizers\implementations\base_tokenizer.py -> build\lib.win-amd64-cpython-39\tokenizers\implementations
#   copying tokenizers\implementations\bert_wordpiece.py -> build\lib.win-amd64-cpython-39\tokenizers\implementations
#   copying tokenizers\implementations\byte_level_bpe.py -> build\lib.win-amd64-cpython-39\tokenizers\implementations
#   copying tokenizers\implementations\char_level_bpe.py -> build\lib.win-amd64-cpython-39\tokenizers\implementations
#   copying tokenizers\implementations\sentencepiece_bpe.py -> build\lib.win-amd64-cpython-39\tokenizers\implementations
#   copying tokenizers\implementations\__init__.py -> build\lib.win-amd64-cpython-39\tokenizers\implementations
#   copying tokenizers\__init__.pyi -> build\lib.win-amd64-cpython-39\tokenizers
#   copying tokenizers\models\__init__.pyi -> build\lib.win-amd64-cpython-39\tokenizers\models
#   copying tokenizers\decoders\__init__.pyi -> build\lib.win-amd64-cpython-39\tokenizers\decoders
#   copying tokenizers\normalizers\__init__.pyi -> build\lib.win-amd64-cpython-39\tokenizers\normalizers
#   copying tokenizers\pre_tokenizers\__init__.pyi -> build\lib.win-amd64-cpython-39\tokenizers\pre_tokenizers
#   copying tokenizers\processors\__init__.pyi -> build\lib.win-amd64-cpython-39\tokenizers\processors
#   copying tokenizers\trainers\__init__.pyi -> build\lib.win-amd64-cpython-39\tokenizers\trainers
#   running build_ext
#   running build_rust
#   error: can't find Rust compiler
#
#   If you are using an outdated pip version, it is possible a prebuilt wheel is available for this package but pip is not able to install from it. Installing from the wheel would avoid the need for a Rust compiler.
#
#   To update pip, run:
#
#       pip install --upgrade pip
#
#   and then retry package installation.
#
#   If you did intend to build this package from source, try installing a Rust compiler from your system package manager and ensure it is on the PATH during installation. Alternatively, rustup (available at https://rustup.rs) is the recommended way to download and update the Rust compiler toolchain.
#   ----------------------------------------
#   ERROR: Failed building wheel for tokenizers
# ERROR: Could not build wheels for tokenizers which use PEP 517 and cannot be installed directly
# Requirement already satisfied: idna<4,>=2.5 in c:\users\developer14\anaconda3\lib\site-packages (from requests->transformers==2.5.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\developer14\anaconda3\lib\site-packages (from requests->transformers==2.5.1) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\developer14\anaconda3\lib\site-packages (from requests->transformers==2.5.1) (2.0.4)
# Requirement already satisfied: click in c:\users\developer14\anaconda3\lib\site-packages (from sacremoses->transformers==2.5.1) (8.0.4)
# Requirement already satisfied: joblib in c:\users\developer14\anaconda3\lib\site-packages (from sacremoses->transformers==2.5.1) (1.1.0)
# Building wheels for collected packages: tokenizers
#   Building wheel for tokenizers (PEP 517): started
#   Building wheel for tokenizers (PEP 517): finished with status 'error'
# Failed to build tokenizers
# Requirement already satisfied: datasets in c:\users\developer14\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: evaluate in c:\users\developer14\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: transformers[sentencepiece] in c:\users\developer14\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (1.21.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (0.10.1)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (2022.2.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (4.64.0)
# Requirement already satisfied: dill<0.3.6 in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: pandas in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (1.4.2)
# Requirement already satisfied: multiprocess in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (0.70.13)
# Requirement already satisfied: responses<0.19 in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (0.18.0)
# Requirement already satisfied: xxhash in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (3.0.0)
# Requirement already satisfied: packaging in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (21.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (2.27.1)
# Requirement already satisfied: pyarrow>=6.0.0 in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (9.0.0)
# Requirement already satisfied: aiohttp in c:\users\developer14\anaconda3\lib\site-packages (from datasets) (3.8.1)
# Requirement already satisfied: sacremoses in c:\users\developer14\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.0.53)
# Requirement already satisfied: filelock in c:\users\developer14\anaconda3\lib\site-packages (from transformers[sentencepiece]) (3.6.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\developer14\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\developer14\anaconda3\lib\site-packages (from transformers[sentencepiece]) (2022.3.15)
# Collecting sentencepiece==0.1.91
#   Using cached sentencepiece-0.1.91.tar.gz (500 kB)
# Requirement already satisfied: protobuf in c:\users\developer14\anaconda3\lib\site-packages (from transformers[sentencepiece]) (3.19.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\developer14\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\developer14\anaconda3\lib\site-packages (from packaging->datasets) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\developer14\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\developer14\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\developer14\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\developer14\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2021.10.8)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\developer14\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\developer14\\AppData\\Local\\Temp\\pip-install-cdk30ajc\\sentencepiece_37f3855b9f784b9c866ad1794dc63107\\setup.py'"'"'; __file__='"'"'C:\\Users\\developer14\\AppData\\Local\\Temp\\pip-install-cdk30ajc\\sentencepiece_37f3855b9f784b9c866ad1794dc63107\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\developer14\AppData\Local\Temp\pip-wheel-wweh6p4j'
#        cwd: C:\Users\developer14\AppData\Local\Temp\pip-install-cdk30ajc\sentencepiece_37f3855b9f784b9c866ad1794dc63107\
#   Complete output (11 lines):
#   C:\Users\developer14\Anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#     warnings.warn(
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   copying sentencepiece.py -> build\lib.win-amd64-3.9
#   running build_ext
#   building '_sentencepiece' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for sentencepiece
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\developer14\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\developer14\\AppData\\Local\\Temp\\pip-install-cdk30ajc\\sentencepiece_37f3855b9f784b9c866ad1794dc63107\\setup.py'"'"'; __file__='"'"'C:\\Users\\developer14\\AppData\\Local\\Temp\\pip-install-cdk30ajc\\sentencepiece_37f3855b9f784b9c866ad1794dc63107\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\developer14\AppData\Local\Temp\pip-record-vp0t5lbt\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\developer14\Anaconda3\Include\sentencepiece'
#          cwd: C:\Users\developer14\AppData\Local\Temp\pip-install-cdk30ajc\sentencepiece_37f3855b9f784b9c866ad1794dc63107\
#     Complete output (13 lines):
#     C:\Users\developer14\Anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#       warnings.warn(
#     running install
#     C:\Users\developer14\Anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     copying sentencepiece.py -> build\lib.win-amd64-3.9
#     running build_ext
#     building '_sentencepiece' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\developer14\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\developer14\\AppData\\Local\\Temp\\pip-install-cdk30ajc\\sentencepiece_37f3855b9f784b9c866ad1794dc63107\\setup.py'"'"'; __file__='"'"'C:\\Users\\developer14\\AppData\\Local\\Temp\\pip-install-cdk30ajc\\sentencepiece_37f3855b9f784b9c866ad1794dc63107\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\developer14\AppData\Local\Temp\pip-record-vp0t5lbt\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\developer14\Anaconda3\Include\sentencepiece' Check the logs for full command output.
# Requirement already satisfied: colorama in c:\users\developer14\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\developer14\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\developer14\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\developer14\anaconda3\lib\site-packages (from aiohttp->datasets) (1.6.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\developer14\anaconda3\lib\site-packages (from aiohttp->datasets) (5.1.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\developer14\anaconda3\lib\site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\developer14\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\developer14\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\developer14\anaconda3\lib\site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\developer14\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: click in c:\users\developer14\anaconda3\lib\site-packages (from sacremoses->transformers[sentencepiece]) (8.0.4)
# Requirement already satisfied: joblib in c:\users\developer14\anaconda3\lib\site-packages (from sacremoses->transformers[sentencepiece]) (1.1.0)
# Building wheels for collected packages: sentencepiece
#   Building wheel for sentencepiece (setup.py): started
#   Building wheel for sentencepiece (setup.py): finished with status 'error'
#   Running setup.py clean for sentencepiece
# Failed to build sentencepiece
# Installing collected packages: sentencepiece
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.1.97
#     Uninstalling sentencepiece-0.1.97:
#       Successfully uninstalled sentencepiece-0.1.97
#     Running setup.py install for sentencepiece: started
#     Running setup.py install for sentencepiece: finished with status 'error'
#   Rolling back uninstall of sentencepiece
#   Moving to c:\users\developer14\anaconda3\lib\site-packages\sentencepiece-0.1.97.dist-info\
#    from C:\Users\developer14\Anaconda3\Lib\site-packages\~entencepiece-0.1.97.dist-info
#   Moving to c:\users\developer14\anaconda3\lib\site-packages\sentencepiece\
#    from C:\Users\developer14\Anaconda3\Lib\site-packages\~entencepiece
# Requirement already satisfied: sentencepiece in c:\users\developer14\anaconda3\lib\site-packages (0.1.97)
# Requirement already satisfied: transformers[torch]==4.3 in c:\users\developer14\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: requests in c:\users\developer14\anaconda3\lib\site-packages (from transformers[torch]==4.3) (2.27.1)
# Requirement already satisfied: packaging in c:\users\developer14\anaconda3\lib\site-packages (from transformers[torch]==4.3) (21.3)
# Requirement already satisfied: sacremoses in c:\users\developer14\anaconda3\lib\site-packages (from transformers[torch]==4.3) (0.0.53)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\developer14\anaconda3\lib\site-packages (from transformers[torch]==4.3) (0.10.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\developer14\anaconda3\lib\site-packages (from transformers[torch]==4.3) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\developer14\anaconda3\lib\site-packages (from transformers[torch]==4.3) (2022.3.15)
# Requirement already satisfied: numpy>=1.17 in c:\users\developer14\anaconda3\lib\site-packages (from transformers[torch]==4.3) (1.21.5)
# Requirement already satisfied: filelock in c:\users\developer14\anaconda3\lib\site-packages (from transformers[torch]==4.3) (3.6.0)
# Requirement already satisfied: torch>=1.0 in c:\users\developer14\anaconda3\lib\site-packages (from transformers[torch]==4.3) (1.12.1)
# Requirement already satisfied: typing-extensions in c:\users\developer14\anaconda3\lib\site-packages (from torch>=1.0->transformers[torch]==4.3) (4.1.1)
# Requirement already satisfied: colorama in c:\users\developer14\anaconda3\lib\site-packages (from tqdm>=4.27->transformers[torch]==4.3) (0.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\developer14\anaconda3\lib\site-packages (from packaging->transformers[torch]==4.3) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\developer14\anaconda3\lib\site-packages (from requests->transformers[torch]==4.3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\developer14\anaconda3\lib\site-packages (from requests->transformers[torch]==4.3) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\developer14\anaconda3\lib\site-packages (from requests->transformers[torch]==4.3) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\developer14\anaconda3\lib\site-packages (from requests->transformers[torch]==4.3) (2021.10.8)
# Requirement already satisfied: six in c:\users\developer14\anaconda3\lib\site-packages (from sacremoses->transformers[torch]==4.3) (1.16.0)
# Requirement already satisfied: click in c:\users\developer14\anaconda3\lib\site-packages (from sacremoses->transformers[torch]==4.3) (8.0.4)
# Requirement already satisfied: joblib in c:\users\developer14\anaconda3\lib\site-packages (from sacremoses->transformers[torch]==4.3) (1.1.0)
# Requirement already satisfied: torch in c:\users\developer14\anaconda3\lib\site-packages (1.12.1)
# Requirement already satisfied: typing-extensions in c:\users\developer14\anaconda3\lib\site-packages (from torch) (4.1.1)
# Requirement already satisfied: tika in c:\users\developer14\anaconda3\lib\site-packages (1.24)
# Requirement already satisfied: requests in c:\users\developer14\anaconda3\lib\site-packages (from tika) (2.27.1)
# Requirement already satisfied: setuptools in c:\users\developer14\anaconda3\lib\site-packages (from tika) (61.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\developer14\anaconda3\lib\site-packages (from requests->tika) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\developer14\anaconda3\lib\site-packages (from requests->tika) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\developer14\anaconda3\lib\site-packages (from requests->tika) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\developer14\anaconda3\lib\site-packages (from requests->tika) (2.0.4)
# Requirement already satisfied: aspose-words in c:\users\developer14\anaconda3\lib\site-packages (22.10.0)

# %%
pip install aspose-cells
# Out:
# Requirement already satisfied: aspose-cells in c:\users\developer14\anaconda3\lib\site-packages (22.10.0)
# Requirement already satisfied: JPype1>=1.2.1 in c:\users\developer14\anaconda3\lib\site-packages (from aspose-cells) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install aspose-words
# Out:
# Requirement already satisfied: aspose-words in c:\users\developer14\anaconda3\lib\site-packages (22.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import tika
from tika import parser
import aspose.words as aw
import nltk
nltk.download('stopwords')
nltk.download('punkt')

import time
import torch
from transformers import T5ForConditionalGeneration,T5Tokenizer
from transformers import (
    AutoModelForSequenceClassification,
    AutoTokenizer,
)
from transformers import pipeline
from nltk import sent_tokenize
import itertools
from datetime import datetime
from multiprocessing import Pool
from multiprocessing import cpu_count
print(cpu_count)
from concurrent.futures import ProcessPoolExecutor
from time import sleep
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\developer14\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\developer14\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <bound method BaseContext.cpu_count of <multiprocessing.context.DefaultContext object at 0x000001369BAEC400>>

# %% [markdown]
# # Importing pretrained models

# %%
model = T5ForConditionalGeneration.from_pretrained('ramsrigouthamg/t5_boolean_questions')
tokenizer = T5Tokenizer.from_pretrained('t5-base')
model_2 = AutoModelForSequenceClassification.from_pretrained("shahrukhx01/roberta-base-boolq")
tokenizer_2 = AutoTokenizer.from_pretrained("shahrukhx01/roberta-base-boolq")
question_answerer = pipeline("question-answering")

# %% [markdown]
# # **Import File**

# %%
import json
import requests
request=requests.get("https://generate-questions.devbyopeneyes.com/api/getFileData/634f8180bad815867802e6f2")
resp= request.json()
file_path=(resp["data"]["file_path"])
_id=(resp["data"]["_id"])
number_of_question=(resp["data"]["number_of_question"])
file_type=(resp["data"]["file_type"])
if file_type == "pdf":
  FileName=file_path
  doc = aw.Document(FileName)
  doc.save("File.docx")
  Parse=parser.from_file("File.docx")
  data=[]
  for i in (Parse['content'].strip().split('\n')): 
    if len(i.split())<5:
      pass
    else: 
      data.append(i)
  Text=data[1:-1]
else:
  FileName=file_path
  Parse=parser.from_file(FileName)
  data=[]
  for i in (Parse['content'].strip().split('\n')): 
    if len(i.split())<5:
      pass
    else: 
      data.append(i)
  Text=data
# Out:
# 2022-10-19 10:31:19,246 [MainThread  ] [INFO ]  Retrieving https://drive.google.com/u/0/uc?id=1Bmro_TkSznwiH2aZAHaKk9yNLSJi-7Wj&export=download to C:\Users\DEVELO~1\AppData\Local\Temp/u-0-uc.
# 2022-10-19 10:31:28,122 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.24/tika-server-1.24.jar to C:\Users\DEVELO~1\AppData\Local\Temp\tika-server.jar.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\tika\tika.py:798, in getRemoteJar(urlOrPath, destPath)
#     797 try:
# --> 798     urlretrieve(urlOrPath, destPath)
#     799 except IOError:
#     800     # monkey patch fix for SSL/Windows per Tika-Python #54
#     801     # https://github.com/chrismattmann/tika-python/issues/54
#
# File ~\Anaconda3\lib\urllib\request.py:239, in urlretrieve(url, filename, reporthook, data)
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#
# File ~\Anaconda3\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\Anaconda3\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~\Anaconda3\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File ~\Anaconda3\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     560 args = (dict, 'default', 'http_error_default') + orig_args
# --> 561 return self._call_chain(*args)
#
# File ~\Anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     493 func = getattr(handler, meth_name)
# --> 494 result = func(*args)
#     495 if result is not None:
#
# File ~\Anaconda3\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 9>()
#      21 else:
#      22   FileName=file_path
# ---> 23   Parse=parser.from_file(FileName)
#      24   data=[]
#      25   for i in (Parse['content'].strip().split('\n')):
#
# File ~\Anaconda3\lib\site-packages\tika\parser.py:40, in from_file(filename, serverEndpoint, service, xmlContent, headers, config_path, requestOptions)
#      24 '''
#      25 Parses a file for metadata and content
#      26 :param filename: path to file which needs to be parsed or binary file using open(path,'rb')
#    (...)
#      37         'content' has a str value and metadata has a dict type value.
#      38 '''
#      39 if not xmlContent:
# ---> 40     output = parse1(service, filename, serverEndpoint, headers=headers, config_path=config_path, requestOptions=requestOptions)
#      41 else:
#      42     output = parse1(service, filename, serverEndpoint, services={'meta': '/meta', 'text': '/tika', 'all': '/rmeta/xml'},
#      43                         headers=headers, config_path=config_path, requestOptions=requestOptions)
#
# File ~\Anaconda3\lib\site-packages\tika\tika.py:336, in parse1(option, urlOrPath, serverEndpoint, verbose, tikaServerJar, responseMimeType, services, rawResponse, headers, config_path, requestOptions)
#     334 headers.update({'Accept': responseMimeType, 'Content-Disposition': make_content_disposition_header(path.encode('utf-8') if type(path) is unicode_string else path)})
#     335 with urlOrPath if _is_file_object(urlOrPath) else open(path, 'rb') as f:
# --> 336     status, response = callServer('put', serverEndpoint, service, f,
#     337                                   headers, verbose, tikaServerJar, config_path=config_path,
#     338                                   rawResponse=rawResponse, requestOptions=requestOptions)
#     340 if file_type == 'remote': os.unlink(path)
#     341 return (status, response)
#
# File ~\Anaconda3\lib\site-packages\tika\tika.py:531, in callServer(verb, serverEndpoint, service, data, headers, verbose, tikaServerJar, httpVerbs, classpath, rawResponse, config_path, requestOptions)
#     529 global TikaClientOnly
#     530 if not TikaClientOnly:
# --> 531     serverEndpoint = checkTikaServer(scheme, serverHost, port, tikaServerJar, classpath, config_path)
#     533 serviceUrl  = serverEndpoint + service
#     534 if verb not in httpVerbs:
#
# File ~\Anaconda3\lib\site-packages\tika\tika.py:592, in checkTikaServer(scheme, serverHost, port, tikaServerJar, classpath, config_path)
#     590 if not alreadyRunning:
#     591     if not os.path.isfile(jarPath) and urlp.scheme != '':
# --> 592         getRemoteJar(tikaServerJar, jarPath)
#     594     if not checkJarSig(tikaServerJar, jarPath):
#     595         os.remove(jarPath)
#
# File ~\Anaconda3\lib\site-packages\tika\tika.py:808, in getRemoteJar(urlOrPath, destPath)
#     806     if os.path.exists(destPath) and os.path.isfile(destPath):
#     807         os.remove(destPath)
# --> 808     urlretrieve(urlOrPath, destPath)
#     810 return (destPath, 'remote')
#
# File ~\Anaconda3\lib\urllib\request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#     242     # Just return the local path and the "headers" for file://
#     243     # URLs. No sense in performing a copy unless requested.
#
# File ~\Anaconda3\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\Anaconda3\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~\Anaconda3\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File ~\Anaconda3\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File ~\Anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~\Anaconda3\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
start = time.time()

# %% [markdown]
# # Code

# %%
# Text Cleaning

def Preprocessing(task1):
  
  sentences = sent_tokenize(task1)
  sentence_to_words=[]
  for i in sentences[0:]:
   sentence_to_words.extend(i.split())  
  tokens = [ w for w in sentence_to_words if w[0]!='[' and w[-1]!= ']' ]
  import string
  remove = string.punctuation
  import re 
  remove = remove.replace(".", "").replace("–", "").replace(",", "")
  pattern = r"[{}]".format(re.escape(remove))
  table = str.maketrans('', '', pattern)
  stripped = [w.translate(table) for w in tokens]
  words_to_sentense=' '.join(stripped)
  words_to_sentense
  sentences_new = sent_tokenize(words_to_sentense)
  return sentences_new

# In-built functions

def greedy_decoding (inp_ids,attn_mask):
  greedy_output = model.generate(input_ids=inp_ids, attention_mask=attn_mask, max_length=256)
  Question =  tokenizer.decode(greedy_output[0], skip_special_tokens=True,clean_up_tokenization_spaces=True)
  return Question.strip().capitalize()


def beam_search_decoding (inp_ids,attn_mask):
  beam_output = model.generate(input_ids=inp_ids,
                                attention_mask=attn_mask,
                                max_length=256,
                              num_beams=1,
                              num_return_sequences=1,
                              no_repeat_ngram_size=3,
                              early_stopping=True
                              )
  Questions = [tokenizer.decode(out, skip_special_tokens=True, clean_up_tokenization_spaces=True) for out in
              beam_output]
  return [Question.strip().capitalize() for Question in Questions]


# Generate Question & Context

def Questions_Context(task2):
    max_len = 512
    context_list=[]
    question_list=[]

    for i in task2: 
      encoding = tokenizer.encode_plus(i, return_tensors="pt", add_special_tokens=True,max_length=max_len, truncation=True,padding=True)
      input_ids, attention_masks = encoding["input_ids"], encoding["attention_mask"]
      context_list.append(i)
      question_append = beam_search_decoding(input_ids,attention_masks) 
      for out in question_append:
        question_list.append(out)
    return question_list,context_list

#Remove Duplicates
def Duplicate_removing(task3):
  new_questions = task3
  new_questions4 = []

  [new_questions4.append(x) for x in new_questions if x not in new_questions4]
  return new_questions4

# Prediction of Answers

def predict(question, passage):
  sequence = tokenizer_2.encode_plus(question, passage, return_tensors="pt")['input_ids']

  logits = model_2(sequence)[0]
  probabilities = torch.softmax(logits, dim=1).detach().cpu().tolist()[0]
  proba_yes = round(probabilities[1], 2)
  proba_no = round(probabilities[0], 2)
  if proba_yes>0.50:
    return True
  else:
    return False 


def Answer_prediction(question_list, context_list):
  answers=[]
  for i, j in zip(question_list, context_list ):
      answers.append(predict(i, j))
  return answers

# Define Questions

def Generate_questions(new_questions4):
  Ques_Ans = []
  for i in new_questions4:
    Ques_Ans.append({"question":i})
  return Ques_Ans

# Ranking of Questions

def Ranking(question_list, context_list):
  de=[]
  for i, j in zip(question_list, context_list ):
    d = question_answerer(question=i, context=j)
    e=d.get("score")
    e_updated=1-float(e)
    accuracy_score="%.2f" % round(e_updated*100, 2)
    de.append(accuracy_score)
  return de

# Get Context, Rank,Answer & Paragraph no.

def Final_dictionary(Ques_Ans,context_list,de,answers):
  for option_index, option in enumerate(Ques_Ans):
      option["context"] = context_list[option_index] # context_list
      option["rank"] = de[option_index]
      option["answer"] = answers[option_index]  
      # option['Paragraph_no']= int(j+1)
  return Ques_Ans

# Sorting as per rank
def Sorting(Ques_Ans):
  final_generated_questions = sorted(Ques_Ans, key=lambda i:float(i['rank']),reverse=True)
  return final_generated_questions

# Extract single list from nested list
def flatten(list_of_lists):
    return list(itertools.chain.from_iterable(list_of_lists))

# define user required questions
generate_ques=int(number_of_question)

# Pipeline

def Pipeline(text):
  a=Preprocessing(text)                    # Text cleaning & pre-processing
  b=Questions_Context(a)                   # generate questions from context
  c=Duplicate_removing(b)                  # remove duplicate questions & context
  d= Answer_prediction(c[0],c[1])          # Answer prediction fron questions & context
  e=Generate_questions(c[0])               # Getting questions in dictionary
  f=Ranking(c[0],c[1])                     # find rank from question list & context list
  g=Final_dictionary(e,c[1],f,d)           # Final dictionary consisting question, context, rank & answer
  return g

# %%
# j=0
# Final_generated_ques=[]
# while j< len(Text):
#   text=Text[j]  
#   x=Pipeline(text)
#   Final_generated_ques.append(x)  
#   if j==len(Text):
#     break
#   j+=1 

# h= flatten(Final_generated_ques) # Flattening nested list
# Boolean_Questions=Sorting(h) # Our Final boolean questions with sorting

# %%
#### Using Multiprocessing Pool method

# pool = Pool(processes=2)
# inputs = Text
# outputs = pool.map(Pipeline, inputs)
# outputs
# x=1
# Final_list=[]  
# for i in outputs:
#   Final_new=[]
#   for j in i:
#     j['Paragraph_no']=x
#     Final_new.append(j)
#   x+=1
#   Final_list.append(Final_new)

# Final_list # Boolean questions without sorting on ranking

###  Using Process Pool executer which have multiprocessing & multi-threading

result =[]
with ProcessPoolExecutor(max_workers=2) as exe:
  exe.submit(Pipeline,2)
  result = exe.map(Pipeline,Text)

outputs=list(result)

x=1
Final_list=[]  
for i in outputs:
  Final_new=[]
  for j in i:
    j['Paragraph_no']=x
    Final_new.append(j)
  x+=1
  Final_list.append(Final_new)

h= flatten(Final_list) # Flattening nested list
Boolean_Questions=Sorting(h) # Our Final boolean questions with sorting

# %%
Boolean_Questions

# %%
end = time.time()

# %%
from datetime import datetime

dt1 = datetime.fromtimestamp(start)
dt2 = datetime.fromtimestamp(end)
total_time = dt2 - dt1
total_time

# %% [markdown]
# ## **Final Output , User Validation & Post Generated Questions**

# %%
if generate_ques > len(Boolean_Questions) or generate_ques == 0: 
  print("please give value between 1 to {}".format(len(Boolean_Questions)))
else:
    middle_index = generate_ques
    user_required_questions = Boolean_Questions[:middle_index]
    other_questions = Boolean_Questions[middle_index:]

    
    for question_index, question in enumerate(user_required_questions):
      question["question_id"]= question_index +1

    for question_index, question in enumerate(other_questions):
      question["question_id"]= question_index +1

# %%
url="https://generate-questions.devbyopeneyes.com/api/GenerateQuestions" 
headers = {'Content-Type':'application/json','Accept':'application/json'}
post_array ={"id" : _id,
       "questions" : user_required_questions,
       "other_questions" : other_questions,
       "upload_process_time": str(total_time)
  }
status = requests.post(url,headers=headers,data=json.dumps(post_array))

# %%
post_array

# %% [markdown]
# # Insert regenerate code below

# %%
original_context = """ This story is about lencho a dedicated farmer and how he places trust in god to help him out of his misery. """
original_answer = "True"
old_question = """ Did a hail storm ruin the lencho farm? """
question_no = 13
question_from = "other question"
question_type="Boolean"

# %%
import time
import torch
from IPython.utils.path import ENOLINK
from transformers import T5ForConditionalGeneration,T5Tokenizer
from transformers import pipeline
from transformers import (
    AutoModelForSequenceClassification,
    AutoTokenizer,
)


def regenerte_quest(data_text, data_answer,data_old_quest,data_question_no,data_question_from,data_question_type):
  
  model = T5ForConditionalGeneration.from_pretrained('ramsrigouthamg/t5_boolean_questions')
  tokenizer = T5Tokenizer.from_pretrained('t5-base')
  

  def topkp_decoding (inp_ids,attn_mask):
    topkp_output = model.generate(input_ids=inp_ids,
                                  attention_mask=attn_mask,
                                  max_length=256,
                                do_sample=True,
                                top_k=40,
                                top_p=0.80,
                                num_return_sequences=1,
                                  no_repeat_ngram_size=2,
                                  early_stopping=True
                                )
    Questions = [tokenizer.decode(out, skip_special_tokens=True,clean_up_tokenization_spaces=True) for out in topkp_output]
    return [Question.strip().capitalize() for Question in Questions]

  max_len = 512
  encoding = tokenizer.encode_plus(data_text, return_tensors="pt", add_special_tokens=True,max_length=max_len, truncation=True,padding=True)
  input_ids, attention_masks = encoding["input_ids"], encoding["attention_mask"]
  question_append_topk = topkp_decoding(input_ids,attention_masks)
  for i in question_append_topk:
    regenerate_question = i

  question_answerer = pipeline("question-answering")
  d = question_answerer(question=question_append_topk, context=data_text)
  e=d.get("score")
  e_updated=1-float(e)
  rank_regenerate="%.2f" % round(e_updated*100, 2)
  
  generted_quest_is=[]
  generted_quest_is.append({"question":regenerate_question, "answer":None,"rank" :rank_regenerate , "old_question":data_old_quest, "question_id" : data_question_no, "question_from":data_question_from,"question_type":data_question_type}) # rnk future
  
  data_text= None
  data_answer = None
  data_old_quest = None
  data_question_no = None
  data_question_from = None
  data_question_type=None
  
  return generted_quest_is

# %%
def regenerate_answer(question,data_text):

    regenerate_answer_model = AutoModelForSequenceClassification.from_pretrained("shahrukhx01/roberta-base-boolq")
    tokenizer_regenerate = AutoTokenizer.from_pretrained("shahrukhx01/roberta-base-boolq")

    sequence = tokenizer_regenerate.encode_plus(question,data_text, return_tensors="pt")['input_ids']
    logits = regenerate_answer_model(sequence)[0]
    probabilities = torch.softmax(logits, dim=1).detach().cpu().tolist()[0]
    proba_yes = round(probabilities[1], 2)
    proba_no = round(probabilities[0], 2)
    if proba_yes>0.5:
      return True
    else:
      return False 

generted_quest_is=regenerte_quest(original_context,original_answer,old_question,question_no,question_from,question_type)
for i in generted_quest_is:
  question = i["question"]
  regenerate_answer=regenerate_answer(question,original_context)
  i["answer"]=regenerate_answer
print(generted_quest_is)
